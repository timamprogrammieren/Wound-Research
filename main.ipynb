# %%
#!pip install numpy torch torchvision scikit-learn opencv-python -U albumentations matplotlib timm

# %%
# !python light_parallel_azh_amp_p2.py \
--batch_size 16 \
    --data_root Data \
        --save_dir runs/multirun6C_BNDPSV_2 \
            --keep_classes "BG,N,D,P,S,V" \
            --weights runs/multirun6C_BNDPSV/trial_00/best.pt \
                --base_seed 42 \
# Out:
# [Trial 00] Params: 14.88M
# [load] Loaded weights from: runs/multirun6C_BNDPSV/trial_00/best.pt
# [Trial 00] Epoch 001 | Train 0.45% | Val 0.75% | Loss 0.6835
# [Trial 00] Epoch 002 | Train 0.59% | Val 0.72% | Loss 0.7574
# [Trial 00] Epoch 003 | Train 0.53% | Val 0.73% | Loss 0.7677
# [Trial 00] Epoch 004 | Train 0.56% | Val 0.73% | Loss 0.7816
# [Trial 00] Epoch 005 | Train 0.58% | Val 0.77% | Loss 0.7137
# [Trial 00] Unfrozen backbones at epoch 6
# [Trial 00] Epoch 006 | Train 0.44% | Val 0.74% | Loss 0.6646
# [Trial 00] Epoch 007 | Train 0.41% | Val 0.74% | Loss 0.7153
# [Trial 00] Epoch 008 | Train 0.58% | Val 0.73% | Loss 0.8244
# [Trial 00] Epoch 009 | Train 0.54% | Val 0.76% | Loss 0.8432
# [Trial 00] Epoch 010 | Train 0.45% | Val 0.75% | Loss 0.9028
# [Trial 00] Epoch 011 | Train 0.48% | Val 0.72% | Loss 0.8579
# [Trial 00] Epoch 012 | Train 0.42% | Val 0.72% | Loss 0.9284
# [Trial 00] Epoch 013 | Train 0.48% | Val 0.72% | Loss 0.8028
# ...
